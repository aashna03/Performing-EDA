# %% [markdown]
# ## MINI PROJECT

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tmdb-movies.csv')
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
df['budget'].nlargest(3)
# Out:
# 2244    425000000
# 3375    380000000
# 7387    300000000
# Name: budget, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df = df[['popularity', 'budget', 'revenue', 'original_title',
       'cast', 'director',   
       'runtime', 'genres', 'production_companies',
       'vote_count', 'vote_average', 'release_year', 'budget_adj',
       'revenue_adj']]
df
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                                                     cast            director  \
# ...

# %%
df.isnull().sum()
# Out:
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# director                  44
# runtime                    0
# genres                    23
# production_companies    1030
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   popularity            10866 non-null  float64
#  1   budget                10866 non-null  int64
#  2   revenue               10866 non-null  int64
#  3   original_title        10866 non-null  object
#  4   cast                  10790 non-null  object
#  5   director              10822 non-null  object
#  6   runtime               10866 non-null  int64
#  7   genres                10843 non-null  object
#  8   production_companies  9836 non-null   object
#  9   vote_count            10866 non-null  int64
#  10  vote_average          10866 non-null  float64
#  11  release_year          10866 non-null  int64
#  12  budget_adj            10866 non-null  float64
#  13  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(5), object(5)
# ...

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9773 entries, 0 to 10865
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   popularity            9773 non-null   float64
#  1   budget                9773 non-null   int64
#  2   revenue               9773 non-null   int64
#  3   original_title        9773 non-null   object
#  4   cast                  9773 non-null   object
#  5   director              9773 non-null   object
#  6   runtime               9773 non-null   int64
#  7   genres                9773 non-null   object
#  8   production_companies  9773 non-null   object
#  9   vote_count            9773 non-null   int64
#  10  vote_average          9773 non-null   float64
#  11  release_year          9773 non-null   int64
#  12  budget_adj            9773 non-null   float64
#  13  revenue_adj           9773 non-null   float64
# dtypes: float64(4), int64(5), object(5)
# ...

# %%
df
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                                                     cast            director  \
# ...

# %%
df['budget'].unique()
# Out:
# array([150000000, 110000000, 200000000, 190000000, 135000000, 155000000,
#        108000000,  74000000, 175000000, 245000000, 176000003,  15000000,
#         88000000, 280000000,  44000000,  48000000, 130000000,  95000000,
#        160000000,  30000000,  40000000,  28000000,  68000000,  81000000,
#         20000000,  61000000,         0,  49000000,  29000000,  58000000,
#          6000000,  50000000,  11000000,  90000000,  75000000,  25000000,
#         10000000,  12000000,   4000000,  11800000,  35000000,  55000000,
#         60000000, 105000000,  26000000,  70000000, 120000001,   3500000,
#         65000000,  50100000, 100000000,  13000000,  99000000,   2500000,
#         34000000,  80000000,  17000000,  31000000,   5000000,  64000000,
#         11930000,   8500000,  23000000,  53000000,   8900000,    700000,
#         14800000,  19500000,   1000000,   8000000,   1800000,   2000000,
#         18000000,    630019,  14000000,  37000000,   7000000,   3000000,
# ...

# %%
df['budget'].nlargest(3)
# Out:
# 2244    425000000
# 3375    380000000
# 7387    300000000
# Name: budget, dtype: int64

# %%
df[df['budget'] == 300000000]
# Out:
#       popularity     budget    revenue  \
# 7387    4.965391  300000000  961000000
#
#                                 original_title  \
# 7387  Pirates of the Caribbean: At World's End
#
#                                                    cast        director  \
# 7387  Johnny Depp|Orlando Bloom|Keira Knightley|Geof...  Gore Verbinski
#
#       runtime                    genres  \
# 7387      169  Adventure|Fantasy|Action
#
#                                    production_companies  vote_count  \
# 7387  Walt Disney Pictures|Jerry Bruckheimer Films|S...        2626
#
#       vote_average  release_year   budget_adj   revenue_adj
# 7387           6.8          2007  315500574.8  1.010654e+09

# %%
bu_df = df[df['budget'] >=100 ]
bu_df = bu_df['budget'].unique()

bu_df_srt = sorted(bu_df)
bu_df_srt[2]
# Out:
# 114

# %%
df[df['budget'] == 114]
# Out:
#       popularity  budget  revenue  original_title  \
# 6179    0.132713     114  6700000  Into the Night
#
#                                                    cast     director  runtime  \
# 6179  Jeff Goldblum|Michelle Pfeiffer|Stacey Pickren...  John Landis      115
#
#                      genres production_companies  vote_count  vote_average  \
# 6179  Comedy|Drama|Thriller   Universal Pictures          24           6.1
#
#       release_year  budget_adj  revenue_adj
# 6179          1985   231.09693  13582012.55

# %%
one_df = df[(df['release_year'] >=2000 )& (df['release_year'] <=2005)]
one_df
# Out:
#       popularity     budget    revenue  \
# 2633    8.575419   93000000  871368364
# 2634    8.021423  125000000  976475550
# 2635    4.436367   15000000   20117339
# 2636    3.851009    6000000    1270522
# 2637    3.204295  115000000  562816256
# ...          ...        ...        ...
# 8876    0.059043          0          0
# 8881    0.031018   40000000   36037909
# 8882    0.029510          0          0
# 8883    0.015997   15000000    5217498
# 8885    0.005784          0          0
#
#                                          original_title  \
# 2633  The Lord of the Rings: The Fellowship of the Ring
# 2634           Harry Potter and the Philosopher's Stone
# 2635                                   Mulholland Drive
# 2636                                       Donnie Darko
# 2637                                     Monsters, Inc.
# ...                                                 ...
# 8876                                     State and Main
# ...

# %%
word_ln=0
i=2633
while  i<=8885:
    try:
        word_ln = word_ln + len(one_df['original_title'][i].split())
        
    except:
        word_ln = word_ln + 0
    finally:
        i = i + 1
word_ln
# Out:
# 4195

# %%
word_avg=word_ln/1479
word_avg
# Out:
# 2.8363759296822177

# %%
df['genres'].unique()
# Out:
# array(['Action|Adventure|Science Fiction|Thriller',
#        'Adventure|Science Fiction|Thriller',
#        'Action|Adventure|Science Fiction|Fantasy', ...,
#        'Adventure|Drama|Action|Family|Foreign',
#        'Comedy|Family|Mystery|Romance',
#        'Mystery|Science Fiction|Thriller|Drama'], dtype=object)

# %%
df.boxplot(column=['revenue'])
# Out:
# <AxesSubplot:>

# %%
df['revenue'].nlargest(1)
# Out:
# 1386    2781505847
# Name: revenue, dtype: int64

# %%
df[df['revenue'] == 2781505847]
# Out:
#       popularity     budget     revenue original_title  \
# 1386    9.432768  237000000  2781505847         Avatar
#
#                                                    cast       director  \
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#       runtime                                    genres  \
# 1386      162  Action|Adventure|Fantasy|Science Fiction
#
#                                    production_companies  vote_count  \
# 1386  Ingenious Film Partners|Twentieth Century Fox ...        8458
#
#       vote_average  release_year   budget_adj   revenue_adj
# 1386           7.1          2009  240886902.9  2.827124e+09

# %%
r_df = df[df['revenue'] >=100 ]
r_df['revenue'].nsmallest(1)
# Out:
# 2618    100
# Name: revenue, dtype: int64

# %%
df[df['revenue'] == 100]
# Out:
#       popularity  budget  revenue original_title  \
# 2618    0.090186       1      100   Lost & Found
#
#                                                    cast      director  \
# 2618  David Spade|Sophie Marceau|Ever Carradine|Step...  Jeff Pollack
#
#       runtime          genres                      production_companies  \
# 2618       95  Comedy|Romance  Alcon Entertainment|Dinamo Entertainment
#
#       vote_count  vote_average  release_year  budget_adj  revenue_adj
# 2618          14           4.8          1999    1.309053   130.905285

# %%
rt_df = df[(df['release_year'] == 2006) & (df['runtime'] !=0)&(df['runtime'] !=270)]

# %%
rt_df.describe()
# Out:
#        popularity        budget       revenue     runtime   vote_count  \
# count  348.000000  3.480000e+02  3.480000e+02  348.000000   348.000000
# mean     0.668333  2.080111e+07  4.669971e+07  101.747126   213.931034
# std      0.712173  3.549875e+07  1.104328e+08   21.362775   434.581167
# min      0.001115  0.000000e+00  0.000000e+00    7.000000    10.000000
# 25%      0.246484  0.000000e+00  0.000000e+00   90.750000    22.000000
# 50%      0.459988  5.000000e+06  2.287690e+06   99.000000    59.500000
# 75%      0.838874  2.600000e+07  4.421977e+07  111.000000   189.000000
# max      5.838503  2.700000e+08  1.065660e+09  185.000000  3181.000000
#
#        vote_average  release_year    budget_adj   revenue_adj
# count    348.000000         348.0  3.480000e+02  3.480000e+02
# mean       5.936494        2006.0  2.249992e+07  5.051363e+07
# std        0.840897           0.0  3.839790e+07  1.194517e+08
# min        2.800000        2006.0  0.000000e+00  0.000000e+00
# ...

# %%
rt_df.boxplot(column=['runtime'])
# Out:
# <AxesSubplot:>

# %%
np.mean(rt_df['runtime'])
# Out:
# 101.74712643678161
